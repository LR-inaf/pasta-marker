# %%
import matplotlib.pyplot as plt
import numpy as np


import sys


sys.path.append("..")

from pastamarkers import pasta, salsa, add_parmesan

# %%
x = np.random.uniform(-1, 1, 1000)
y = np.random.uniform(-1, 1, 1000)
z = np.random.uniform(-1, 1, 1000)

fig, ax = plt.subplots(figsize=(10, 10))

ax.scatter(
    x,
    y,
    marker=pasta.tagliatelle,
    edgecolor="black",
    facecolor="yellow",
    s=1000,
    lw=0.1,
    c=z,
    cmap=salsa.pesto,
)

# Un comment if you want to add parmesan
# add_parmesan(ax)

plt.show()
# Out:
# C:\Users\utente\AppData\Local\Temp\ipykernel_14228\364335874.py:7: UserWarning: You passed both c and facecolor/facecolors for the markers. c has precedence over facecolor/facecolors. This behavior may change in the future.
#   ax.scatter(
