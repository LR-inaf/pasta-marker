# %%
import sys
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

sys.path.append(
    "/home/luca/Scrivania/pastamarker/pasta-marker"
)  # path to the pasta-marker folder
from pastamarkers import markers

# %%
markers_list = [
    x
    for x in markers.__dict__.keys()
    if isinstance(getattr(markers, x), mpl.path.Path)
]
markers_list
# Out:
# ['fiorellino',
#  'tempestine',
#  'puntine',
#  'farfalline',
#  'stelline',
#  'spaghetti',
#  'mafaldine',
#  'pappardelle',
#  'tagliolini',
#  'tagliatelle',
#  'lasagne',
#  'soli',
#  'mezzelune',
#  'ravioli',
#  'cappelletti',
#  'tortellini',
#  'creste',
#  'gnocchi',
#  'conchiglie',
#  'farfalle',
#  'pipe',
#  'spighe',
#  'fiori',
#  'ruote',
#  'maccheroni',
#  'gramigna',
#  'radiatori',
#  'gemelli',
#  'cavatappi',
#  'fusilli2',
#  'fusilli',
#  'garganelli',
#  'tortiglioni',
#  'rigatoni',
#  'penne']

# %%
markers.fiorellino
# Out:
# Path(array([[ -1.57,  -3.71],
#        [  0.93,   0.11],
#        [ -3.51,   3.35],
#        [ -6.26,  -0.83],
#        [ -6.26,  -0.83],
#        [ -9.97,   3.34],
#        [-15.3 ,   1.  ],
#        [-12.21,  -4.33],
#        [-15.4 ,  -6.49],
#        [-14.61, -12.56],
#        [ -9.58, -11.65],
#        [ -9.18, -16.58],
#        [ -0.32, -14.34],
#        [ -2.04, -10.47],
#        [  3.33,  -8.6 ],
#        [  1.43,  -5.06],
#        [ -1.57,  -3.71],
#        [ -1.57,  -3.71],
#        [ -1.57,  -3.71],
#        [ -6.2 ,  -9.28],
#        [ -7.76,  -9.28],
#        [ -9.02,  -8.02],
#        [ -9.02,  -6.46],
#        [ -9.02,  -4.91],
#        [ -7.76,  -3.65],
#        [ -6.2 ,  -3.65],
#        [ -4.65,  -3.65],
#        [ -3.39,  -4.91],
#        [ -3.39,  -6.46],
#        [ -3.39,  -8.02],
#        [ -4.65,  -9.28],
#        [ -6.2 ,  -9.28],
#        [ -6.2 ,  -9.28],
#        [ 11.86,   2.65],
#        [ 11.86,   2.65],
#        [ 13.48,   7.53],
#        [  9.16,  10.71],
#        [  6.33,   5.78],
#        [  3.14,   7.34],
#        [ -1.33,   5.15],
#        [  1.71,   0.31],
#        [ -1.35,  -3.86],
#        [  3.21,  -6.9 ],
#        [  6.12,  -5.15],
#        [  8.32,  -8.97],
#        [ 13.27,  -5.47],
#        [ 11.73,  -2.41],
#        [ 15.93,  -2.65],
#        [ 16.47,   2.38],
#        [ 11.86,   2.65],
#        [ 11.86,   2.65],
#        [ 11.86,   2.65],
#        [  8.7 ,  -2.24],
#        [  7.46,  -2.96],
#        [  5.87,  -2.53],
#        [  5.15,  -1.29],
#        [  4.44,  -0.05],
#        [  4.86,   1.53],
#        [  6.1 ,   2.25],
#        [  7.34,   2.97],
#        [  8.93,   2.54],
#        [  9.64,   1.3 ],
#        [ 10.36,   0.06],
#        [  9.94,  -1.52],
#        [  8.7 ,  -2.24],
#        [  8.7 ,  -2.24],
#        [ -3.09,  10.  ],
#        [ -1.06,  13.5 ],
#        [ -3.83,  16.58],
#        [ -7.24,  13.69],
#        [ -9.85,  16.33],
#        [-14.13,  14.69],
#        [-12.58,   9.99],
#        [-16.47,   8.6 ],
#        [-12.74,   1.93],
#        [ -9.99,   4.17],
#        [ -7.32,   0.24],
#        [ -4.88,   2.53],
#        [ -4.44,   5.24],
#        [ -0.82,   4.05],
#        [  0.88,   8.69],
#        [ -3.09,  10.01],
#        [ -3.09,  10.  ],
#        [ -3.09,  10.  ],
#        [ -6.88,   6.57],
#        [ -8.13,   6.23],
#        [ -9.42,   6.97],
#        [ -9.75,   8.23],
#        [-10.09,   9.48],
#        [ -9.35,  10.77],
#        [ -8.09,  11.11],
#        [ -6.84,  11.44],
#        [ -5.55,  10.7 ],
#        [ -5.21,   9.44],
#        [ -4.88,   8.19],
#        [ -5.62,   6.9 ],
#        [ -6.88,   6.57],
#        [ -6.88,   6.57],
#        [  7.03, -10.15],
#        [  8.39,  -8.29],
#        [  5.58,  -6.32],
#        [  5.07,  -9.37],
#        [  3.57,  -7.46],
#        [  1.44,  -9.66],
#        [  3.78, -11.05],
#        [  0.82, -12.57],
#        [  3.95, -14.6 ],
#        [  5.15, -12.76],
#        [  5.42, -15.85],
#        [  8.94, -13.9 ],
#        [  6.97, -12.09],
#        [  9.48, -12.5 ],
#        [  9.47, -10.08],
#        [  7.03, -10.15],
#        [  7.03, -10.15],
#        [  7.03, -10.15],
#        [  5.65, -11.84],
#        [  5.26, -11.84],
#        [  4.94, -11.52],
#        [  4.94, -11.13],
#        [  4.94, -10.74],
#        [  5.26, -10.43],
#        [  5.65, -10.43],
#        [  6.04, -10.43],
#        [  6.36, -10.74],
#        [  6.36, -11.13],
#        [  6.36, -11.52],
#        [  6.04, -11.84],
#        [  5.65, -11.84],
#        [  5.65, -11.84],
#        [  5.23,  11.51],
#        [  7.87,  12.08],
#        [  5.7 ,  15.19],
#        [  4.  ,  13.  ],
#        [  3.99,  15.16],
#        [  0.7 ,  14.82],
#        [  1.95,  12.2 ],
#        [  1.95,  12.2 ],
#        [ -0.18,  12.24],
#        [  0.62,   9.28],
#        [  2.22,  10.11],
#        [  1.39,   7.53],
#        [  4.77,   7.13],
#        [  4.32,   9.8 ],
#        [  6.33,   8.53],
#        [  7.24,  10.56],
#        [  5.23,  11.51],
#        [  5.23,  11.51],
#        [  5.23,  11.51],
#        [  3.4 ,  10.56],
#        [  3.01,  10.56],
#        [  2.69,  10.87],
#        [  2.69,  11.26],
#        [  2.69,  11.66],
#        [  3.01,  11.97],
#        [  3.4 ,  11.97],
#        [  3.79,  11.97],
#        [  4.11,  11.66],
#        [  4.11,  11.26],
#        [  4.11,  10.87],
#        [  3.79,  10.56],
#        [  3.4 ,  10.56],
#        [  3.4 ,  10.56]]), array([ 1,  4,  4,  4,  2,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,
#         2, 79,  1,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4, 79,  1,
#         2,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  2,
#        79,  1,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4, 79,  1,  4,
#         4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  2, 79,  1,
#         4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4, 79,  1,  4,  4,  4,
#         4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  2, 79,  1,  4,  4,
#         4,  4,  4,  4,  4,  4,  4,  4,  4,  4, 79,  1,  4,  4,  4,  4,  4,
#         4,  2,  4,  4,  4,  4,  4,  4,  4,  4,  4,  2, 79,  1,  4,  4,  4,
#         4,  4,  4,  4,  4,  4,  4,  4,  4, 79], dtype=uint8))

# %%
dir_data = "/home/luca/Scrivania/pastamarker/pasta-marker/test/data/MPD/"  # Change to your data\MPD path


xUV, yUV = np.genfromtxt(dir_data + "UV.csv", delimiter=",", unpack=1)

xB, yB = np.genfromtxt(dir_data + "B.csv", delimiter=",", unpack=1)

xIR, yIR = np.genfromtxt(dir_data + "IR.csv", delimiter=",", unpack=1)


xUV_curve, yUV_curve = np.genfromtxt(
    dir_data + "UV_curve.csv", delimiter=",", unpack=1
)

# %%
marker_kwargs = {"markersize": 25, "color": "r", "markeredgecolor": "r"}

fig, ax = plt.subplots(dpi=150, figsize=(5, 4))

ax.scatter(
    xB,
    yB,
    marker=markers.tortellini,
    s=300,
    color="dodgerblue",
    linewidth=0.2,
    label="B-band",
)
ax.scatter(
    xUV,
    yUV,
    marker=markers.farfalle,
    s=500,
    color="purple",
    linewidth=0.1,
    label="IR-band",
)
ax.scatter(
    xIR,
    yIR,
    marker=markers.fiorellino,
    s=700,
    color="darkred",
    linewidth=0.2,
    label="UV-band",
)

ax.plot(xUV_curve, yUV_curve, color="purple", lw=0.8, ls="--")

plt.legend()
plt.title("Madau, Pozzetti & Dickinson (1998)")
plt.xlabel("redshift")
plt.ylabel(
    r"$\log \rho_\nu \, (\mathrm{erg \, s^{-1} \, Hz^{-1} \, Mpc^{-3}})$"
)
plt.plot()
# Out:
# []
